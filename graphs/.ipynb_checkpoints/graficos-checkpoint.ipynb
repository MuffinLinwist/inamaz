# %% [markdown]
# # Patrones estructurales de los índices

# %%
import matplotlib.pyplot as plt
import numpy as np
w=0.2
x = ["Prefijo", "Sufijo", "Afijo", "Proclítico", "Enclítico", "Clítico", "No marcado"]
S = [0, 4, 1, 3, 0, 1, 0]
A = [1, 4, 0, 4, 0, 0, 0]
P = [0, 3, 0, 2, 2, 0, 2]

bar1 = np.arange(len(x))
bar2 = [i+w for i in bar1]
bar3 = [i+w for i in bar2]

plt.bar(bar1, S, w, color = 'darkslategray', label='S')
plt.bar(bar2, A, w, color = 'cadetblue', label='A')
plt.bar(bar3, P, w, color = 'yellowgreen', label='P')


plt.ylabel("Número de lenguas")
plt.title("Patrones estructurales de los índices")
plt.xticks(bar1+w, x)
plt.legend()


fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('estructura.png', dpi=100)

# %% [markdown]
# # Patrones distribucionales de los índices

# %%
w=0.3
x = ["Gramaticalizado", "Cruzado", "Proíndice"]
S = [0, 8, 1]
A = [0, 8, 1]
P = [0, 5, 1]

bar1 = np.arange(len(x))
bar2 = [i+w for i in bar1]
bar3 = [i+w for i in bar2]

plt.bar(bar1, S, w, color = 'darkslategray', label='S')
plt.bar(bar2, A, w, color = 'cadetblue', label='A')
plt.bar(bar3, P, w, color = 'yellowgreen', label='P')

plt.ylabel("Número de lenguas")
plt.title("Patrones distribucionales de los índices")
plt.xticks(bar1+w, x)
plt.legend()

fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('distribución.png', dpi=100)

# %% [markdown]
# # Locus de la marcación argumental

# %%
w=0.3
x = ["Dentro del verbo", "Fuera del verbo", "Ambos"]
S = [7, 0, 2]
A = [7, 0, 2]
P = [5, 0, 2]

bar1 = np.arange(len(x))
bar2 = [i+w for i in bar1]
bar3 = [i+w for i in bar2]

plt.bar(bar1, S, w, color = 'darkslategray', label='S')
plt.bar(bar2, A, w, color = 'cadetblue', label='A')
plt.bar(bar3, P, w, color = 'yellowgreen', label='P')

plt.ylabel("Número de lenguas")
plt.title("Locus de la marcación argumental")
plt.xticks(bar1+w, x)
plt.legend()

fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('locus.png', dpi=100)

# %% [markdown]
# # Número

# %%
x=0.2
x = ["Prefijo indep.", "Sufijo indep.", "Fusionado", "No marcado"]
S = [0, 2, 9, 0]
A = [0, 1, 9, 0]
P = [0, 1, 6, 2]

bar1 = np.arange(len(x))
bar2 = [i+w for i in bar1]
bar3 = [i+w for i in bar2]

plt.bar(bar1, S, w, color = 'darkslategray', label='S')
plt.bar(bar2, A, w, color = 'cadetblue', label='A')
plt.bar(bar3, P, w, color = 'yellowgreen', label='P')

plt.ylabel("Número de lenguas")
plt.title("Marcación de número de argumentos")
plt.xticks(bar1+w, x)
plt.legend()


fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('numero.png', dpi=100)
